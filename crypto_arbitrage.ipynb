# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
import warnings

# %matplotlib inline

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Reading in the CSV file called "bitstamp.csv" using the Path module. 
bitstamp = pd.read_csv(Path("./Resources/bitstamp.csv"),
                       index_col = "Timestamp",
                       parse_dates = True,
                       infer_datetime_format = True)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
display(bitstamp.head())
display(bitstamp.tail())
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# ...

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
coinbase = pd.read_csv(Path("./Resources/coinbase.csv"),
                       index_col = "Timestamp",
                       parse_dates = True,
                       infer_datetime_format = True)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
display(coinbase.head())
display(coinbase.tail())
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# ...

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# Dropping all NaNs and missing values in the bitstamp DataFrame.
bitstamp_df = bitstamp.dropna()

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Using the str.replace function to remove the dollar sign, $.
bitstamp_df.loc[:,"Close"] = bitstamp_df.loc[:,'Close'].str.replace("$","")

# Display the bitstamp dataframe.
display(bitstamp_df)
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   6922.56    1.044354
# 2018-03-31 23:56:00   6922.02   6922.02   6918.00   6920.32    3.069539
# 2018-03-31 23:57:00   6920.33   6936.42   6920.33   6934.72   28.239049
# 2018-03-31 23:58:00   6927.65   6929.42   6927.65   6927.65    0.839507
# 2018-03-31 23:59:00   6929.98   6929.98   6928.00   6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close column data type to a float.
bitstamp_df.loc[:,"Close"] = bitstamp_df.loc[:,'Close'].astype("float")

# Verify that all data type is float.
bitstamp_df.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Verify that the dataframe as no duplicate values.
bitstamp_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Dropping all NaNs and missing values in the bitstamp DataFrame.
coinbase_df = coinbase.dropna()

# %%
# Using the str.replace function to remove the dollar sign, $.
coinbase_df.loc[:,"Close"] = coinbase_df.loc[:,'Close'].str.replace("$","")

# Display the coinbase dataframe.
display(coinbase_df)
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6945.20   6948.06   6930.00    6930.0    5.802288
# 2018-03-31 23:56:00   6930.00   6930.01   6930.00   6930.01    0.625053
# 2018-03-31 23:57:00   6930.01   6933.91   6930.01   6933.91    0.776431
# 2018-03-31 23:58:00   6933.91   6938.00   6933.90   6937.31    0.133413
# 2018-03-31 23:59:00   6937.30   6937.30   6931.09    6934.0    1.012720
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
# Convert the Close column data type to a float.
coinbase_df.loc[:,"Close"] = coinbase_df.loc[:,'Close'].astype("float")

# Verify that all data type is float.
coinbase_df.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
# Verify that the dataframe as no duplicate values.
coinbase_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Using the loc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame.
bitstamp_sliced = bitstamp_df.loc[:,"Close"]

# Display the first five rows of the DataFrame.
display(bitstamp_sliced.head())
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
# Using loc to select `Timestamp (the index)` and `Close` from coinbase DataFrame.
coinbase_sliced = coinbase_df.loc[:,"Close"]

# Display the first five rows of the DataFrame.
display(coinbase_sliced.head())
# Out:
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close, dtype: float64

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Summary statistics for the bitstamp DataFrame.
bitstamp_sliced.describe()
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
# Summary statistics for the coinbase DataFrame.
coinbase_sliced.describe()
# Out:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close, dtype: float64

# %%
# Line plot Graph for the bitstamp DataFrame for the full length of time in the dataset.
bitstamp_sliced.plot(figsize=(25,10), title="Bitstamp Dataframe from Jan to March 2018", color="red")
# Out:
# <AxesSubplot:title={'center':'Bitstamp Dataframe from Jan to March 2018'}, xlabel='Timestamp'>

# %%
# Line plot Graph for the coinbase DataFrame for the full length of time in the dataset.
coinbase_sliced.plot(figsize=(25,10), title="Coinbase Dataframe from Jan to March 2018", color="blue")
# Out:
# <AxesSubplot:title={'center':'Coinbase Dataframe from Jan to March 2018'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames from January to March 2018.
bitstamp_sliced.plot(legend=True, figsize=(25,10), title="Bitstamp vs Coinbase Dataframe from Jan to March 2018", color="red", label="Bitstamp")
coinbase_sliced.plot(legend=True, figsize=(25,10), color="blue", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp vs Coinbase Dataframe from Jan to March 2018'}, xlabel='Timestamp'>

# %%
# Overlay plot that visualizes the price action of both DataFrames for January 2018 using the loc and plot functions . 
bitstamp_sliced.loc["2018-01-01":"2018-01-31"].plot(legend=True, figsize=(25,10), title="Bitstamp vs Coinbase Dataframe for Jan 2018", color="red", label="Bitstamp")
coinbase_sliced.loc["2018-01-01":"2018-01-31"].plot(legend=True, figsize=(25,10), color="blue", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp vs Coinbase Dataframe for Jan 2018'}, xlabel='Timestamp'>

# %%
# Overlay plot that visualizes the price action of both DataFrames for March 2018 using the loc and plot functions . 
bitstamp_sliced.loc["2018-03-01":"2018-03-31"].plot(legend=True, figsize=(25,10), title="Bitstamp vs Coinbase Dataframe for March 2018", color="red", label="Bitstamp")
coinbase_sliced.loc["2018-03-01":"2018-03-31"].plot(legend=True, figsize=(25,10), color="blue", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp vs Coinbase Dataframe for March 2018'}, xlabel='Timestamp'>

# %%
# BitStamp Min for March 2018.
bitstamp_sliced_march_min = bitstamp_sliced.loc["2018-03-01":"2018-03-31"].min()

#BitStamp Max for March 2018.
bitstamp_sliced_march_max = bitstamp_sliced.loc["2018-03-01":"2018-03-31"].max()

#BitStamp Spread for March 2018.
bitstamp_sliced_march_spread = bitstamp_sliced_march_max - bitstamp_sliced_march_min

# Print Bitstamp Spread for March 2018.
print(f"The Bitstamp Spread for March 2018 is: {bitstamp_sliced_march_spread: .2f}")
# Out:
# The Bitstamp Spread for March 2018 is:  5093.22

# %%
# BitStamp Min for January 2018.
bitstamp_sliced_jan_min = bitstamp_sliced.loc["2018-01-01":"2018-01-31"].min()

#BitStamp Max for January 2018.
bitstamp_sliced_jan_max = bitstamp_sliced.loc["2018-01-01":"2018-01-31"].max()

#BitStamp Spread for January 2018.
bitstamp_sliced_jan_spread = bitstamp_sliced_jan_max - bitstamp_sliced_jan_min

# Print Bitstamp Spread for January 2018.
print(f"The Bitstamp Spread for January 2018 is: {bitstamp_sliced_jan_spread: .2f}")
# Out:
# The Bitstamp Spread for January 2018 is:  8012.98

# %%
# Summary statistics for the Bitstamp January DataFrame.
bitstamp_sliced.loc["2018-01-01":"2018-01-31"].describe()
# Out:
# count    44536.000000
# mean     12872.410347
# std       1926.531347
# min       9222.000000
# 25%      11223.337500
# 50%      12678.020000
# 75%      14354.482500
# max      17234.980000
# Name: Close, dtype: float64

# %%
# Summary statistics for the Bitstamp March DataFrame.
bitstamp_sliced.loc["2018-03-01":"2018-03-31"].describe()
# Out:
# count    44295.000000
# mean      9003.946775
# std       1275.114083
# min       6594.240000
# 25%       8143.750000
# 50%       8721.370000
# 75%       9642.080000
# max      11687.460000
# Name: Close, dtype: float64

# %%
# Spread change percentage from January 2018 to March 2018 for Bitstamp. 
bitstamp_spread_change = (1-(bitstamp_sliced_march_spread/bitstamp_sliced_jan_spread))*100

# Print the percentage change.
print(f"The degree of spread change as decreased {bitstamp_spread_change: .1f}% from January to March 2018.")
# Out:
# The degree of spread change as decreased  36.4% from January to March 2018.

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** *The degree of spread changed significantly over time from January (8,012.98) to March (5,093.22) decreasing from aproximately 36.4%.*

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Overlay plot that visualizes the two dataframes over a period of one day (January 2018).  
bitstamp_sliced.loc["2018-01-16"].plot(legend=True, figsize=(25,10), title="Bitstamp vs Coinbase Dataframe Jan 16th 2018", color="red", label="Bitstamp")
coinbase_sliced.loc["2018-01-16"].plot(legend=True, figsize=(25,10), color="blue", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp vs Coinbase Dataframe Jan 16th 2018'}, xlabel='Timestamp'>

# %%
# Display of the summary statistics for Bitstamp and Coinbase on January 1st 2018.
display(bitstamp_sliced.loc["2018-01-16"].describe())
display(coinbase_sliced.loc["2018-01-16"].describe())
# Out:
# count     1440.000000
# mean     11763.118694
# std        694.123446
# min      10172.020000
# 25%      11299.990000
# 50%      11730.175000
# 75%      12156.400000
# max      13229.560000
# Name: Close, dtype: float64
# count     1419.000000
# mean     11791.307942
# std        705.032969
# min       9969.000000
# 25%      11299.615000
# 50%      11744.010000
# 75%      12201.205000
# max      13239.990000
# Name: Close, dtype: float64

# %%
# Box plot visualization of the arbitrage spread on January 16th 2018 for Bitstamp.
bitstamp_sliced.loc["2018-01-16"].plot.box(column="Close")
# Out:
# <AxesSubplot:>

# %%
# Box plot visualization of the arbitrage spread on January 16th 2018 for Coinbase.
coinbase_sliced.loc["2018-01-16"].plot.box(column="Close")
# Out:
# <AxesSubplot:>

# %%
# Overlay plot that visualizes the two dataframes on February 14th 2018. 
bitstamp_df['Close'].loc['2018-02-17'].plot(legend=True, figsize=(25,10), title="Bitstamp vs Coinbase Dataframe Feb 17th 2018", color="red", label="Bitstamp")
coinbase_df['Close'].loc['2018-02-17'].plot(legend=True, figsize=(25,10), color="blue", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp vs Coinbase Dataframe Feb 17th 2018'}, xlabel='Timestamp'>

# %%
# Summary statistics for Bitstamp and Coinbase on Feb 17th 2018.
display(bitstamp_sliced.loc["2018-02-17"].describe())
display(coinbase_sliced.loc["2018-02-17"].describe())
# Out:
# count     1440.000000
# mean     10828.695507
# std        177.062804
# min      10483.000000
# 25%      10711.555000
# 50%      10788.140000
# 75%      10890.167500
# max      11294.990000
# Name: Close, dtype: float64
# count     1440.000000
# mean     10842.557785
# std        173.866355
# min      10499.990000
# 25%      10730.542500
# 50%      10806.380000
# 75%      10919.230000
# max      11299.100000
# Name: Close, dtype: float64

# %%
# Box plot visualization of the arbitrage spread on February 17th 2018 for Bitstamp.
bitstamp_sliced.loc["2018-02-17"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
# Box plot visualization of the arbitrage spread on February 17th 2018 for Coinbase.
coinbase_sliced.loc["2018-02-17"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
# Overlay plot that visualizes the two dataframes on March 21st 2018.  
bitstamp_df['Close'].loc['2018-03-21'].plot(legend=True, figsize=(25,10), title="Bitstamp vs Coinbase Dataframe March 21st 2018", color="red", label="Bitstamp")
coinbase_df['Close'].loc['2018-03-21'].plot(legend=True, figsize=(25,10), color="blue", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp vs Coinbase Dataframe March 21st 2018'}, xlabel='Timestamp'>

# %%
# Summary statistics for Bitstamp and Coinbase late DataFrame.
display(bitstamp_sliced.loc["2018-03-21"].describe())
display(coinbase_sliced.loc["2018-03-21"].describe())
# Out:
# count    1432.000000
# mean     8993.482004
# std        85.969896
# min      8755.650000
# 25%      8916.060000
# 50%      9024.275000
# 75%      9065.010000
# max      9179.000000
# Name: Close, dtype: float64
# count    1440.000000
# mean     8990.512486
# std        88.543947
# min      8753.010000
# 25%      8908.000000
# 50%      9023.550000
# 75%      9066.195000
# max      9174.000000
# Name: Close, dtype: float64

# %%
# Box plot visualization of the arbitrage spread on March 22nd 2018 for Bitstamp.
bitstamp_sliced.loc["2018-03-22"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
# Box plot visualization of the arbitrage spread on March 22nd 2018 for Coinbase.
coinbase_sliced.loc["2018-03-22"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# Arbitrage spread between the two exchanges for Jan 16th, Feb 14th and March 21st by subtracting the lower-priced exchange from the higher-priced one.
arbitrage_spread_early = bitstamp_df["Close"].loc["2018-01-16"]-coinbase_df["Close"].loc["2018-01-16"]
arbitrage_spread_middle = coinbase_df["Close"].loc["2018-02-15"]-bitstamp_df["Close"].loc["2018-02-15"]
arbitrage_spread_late = coinbase_df["Close"].loc["2018-03-22"]-bitstamp_df["Close"].loc["2018-03-22"]

# Summary statistics for each arbitrage spread DataFrame using a conditional statement.
display(arbitrage_spread_early[arbitrage_spread_early>0].describe())
display(arbitrage_spread_middle[arbitrage_spread_middle>0].describe())
display(arbitrage_spread_late[arbitrage_spread_late>0].describe())
# Out:
# count    451.000000
# mean      40.645477
# std       47.387457
# min        0.010000
# 25%       10.010000
# 50%       26.830000
# 75%       49.330000
# max      275.920000
# Name: Close, dtype: float64
# count    466.000000
# mean      11.267489
# std        8.653952
# min        0.010000
# 25%        4.372500
# 50%        9.795000
# 75%       15.797500
# max       48.800000
# Name: Close, dtype: float64
# count    461.000000
# mean       5.962820
# std        5.614386
# min        0.010000
# 25%        1.930000
# 50%        4.230000
# 75%        8.850000
# max       50.810000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# Spread returns for instances with a positive (> 0) arbitrage spread.
spread_return_early= arbitrage_spread_early[arbitrage_spread_early>0]/coinbase_df["Close"].loc["2018-01-16"]
spread_return_middle= arbitrage_spread_middle[arbitrage_spread_middle>0]/bitstamp_df["Close"].loc["2018-02-15"]
spread_return_late= arbitrage_spread_late[arbitrage_spread_late>0]/bitstamp_df["Close"].loc["2018-03-22"]

# Display of the spread return DataFrame.
display(spread_return_early.describe())
display(spread_return_middle.describe())
display(spread_return_late.describe())
# Out:
# count    4.510000e+02
# mean     3.586325e-03
# std      4.271174e-03
# min      8.130075e-07
# 25%      8.524783e-04
# 50%      2.322324e-03
# 75%      4.282673e-03
# max      2.415249e-02
# Name: Close, dtype: float64
# count    466.000000
# mean       0.001135
# std        0.000865
# min        0.000001
# 25%        0.000437
# 50%        0.000990
# 75%        0.001595
# max        0.004880
# Name: Close, dtype: float64
# count    461.000000
# mean       0.000685
# std        0.000648
# min        0.000001
# 25%        0.000221
# 50%        0.000484
# 75%        0.001001
# max        0.005832
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# Trades with positive returns exceeding the 1% minimum threshold (.01) that you need to cover your costs.
profitable_trades_early = spread_return_early[spread_return_early>0.01]
profitable_trades_middle = spread_return_middle[spread_return_middle>0.01]
profitable_trades_late = spread_return_late[spread_return_late>0.01]

# Display of the first five profitable trades.
display(profitable_trades_early.head())
display(profitable_trades_middle.head())
display(profitable_trades_late.head())
# Out:
# Timestamp
# 2018-01-16 07:39:00    0.010341
# 2018-01-16 08:43:00    0.013533
# 2018-01-16 08:44:00    0.013085
# 2018-01-16 08:45:00    0.013013
# 2018-01-16 08:46:00    0.017702
# Name: Close, dtype: float64
# Series([], Name: Close, dtype: float64)
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# Summary statistics for the profitable trades which have spread returns greater than 1%.
display(profitable_trades_early.describe())
display(profitable_trades_middle.describe())
display(profitable_trades_late.describe())
# Out:
# count    36.000000
# mean      0.015715
# std       0.003830
# min       0.010341
# 25%       0.012960
# 50%       0.014925
# 75%       0.018038
# max       0.024152
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# Potential profit per trade in dollars.
profit_early = profitable_trades_early * coinbase_df["Close"].loc["2018-01-16"]
profit_middle = profitable_trades_middle * coinbase_df["Close"].loc["2018-02-15"]
profit_late = profitable_trades_late * coinbase_df["Close"].loc["2018-03-22"]

# Dropping any missing values from the profit DataFrame.
profit_per_trade_early = profit_early.dropna()
profit_per_trade_middle = profit_middle.dropna()
profit_per_trade_late = profit_late.dropna()

# Display the early profit DataFrame.
display(profit_per_trade_early)
display(profit_per_trade_middle)
display(profit_per_trade_late)
# Out:
# Timestamp
# 2018-01-16 07:39:00    124.56
# 2018-01-16 08:43:00    158.91
# 2018-01-16 08:44:00    153.10
# 2018-01-16 08:45:00    152.18
# 2018-01-16 08:46:00    207.82
# 2018-01-16 08:47:00    214.26
# 2018-01-16 08:48:00    170.03
# 2018-01-16 08:49:00    155.02
# 2018-01-16 08:50:00    190.45
# 2018-01-16 08:51:00    229.71
# 2018-01-16 08:52:00    247.04
# 2018-01-16 08:53:00    219.35
# 2018-01-16 08:54:00    160.96
# 2018-01-16 08:55:00    275.92
# 2018-01-16 08:56:00    192.98
# 2018-01-16 08:57:00    131.17
# 2018-01-16 08:58:00    222.15
# 2018-01-16 08:59:00    163.98
# 2018-01-16 09:00:00    192.00
# 2018-01-16 09:01:00    121.33
# 2018-01-16 09:02:00    142.52
# 2018-01-16 09:04:00    135.86
# 2018-01-16 14:04:00    134.66
# 2018-01-16 16:35:00    138.26
# 2018-01-16 16:36:00    170.86
# 2018-01-16 16:37:00    247.61
# 2018-01-16 16:38:00    179.66
# 2018-01-16 17:04:00    177.97
# 2018-01-16 17:08:00    114.32
# 2018-01-16 17:09:00    110.00
# ...

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Summary statistics for the early profit per trade DataFrame.
display(profit_per_trade_early.describe())
display(profit_per_trade_middle.describe())
display(profit_per_trade_late.describe())
# Out:
# count     36.000000
# mean     174.062222
# std       41.263561
# min      110.000000
# 25%      141.455000
# 50%      167.005000
# 75%      201.947500
# max      275.920000
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
# Plot Graph of the results for the early profit per trade DataFrame.
profit_per_trade_early.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Plot Graph of the results for the middle profit per trade DataFrame.
profit_per_trade_middle.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Plot Graph of the results for the late profit per trade DataFrame.
profit_per_trade_late.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Sum of the potential profits for the early profit per trade DataFrame.
print(f"The potential arbitrage profits on January 16th is: {profit_per_trade_early.sum(): .2f}$")
print(f"The potential arbitrage profits on February 17th is: {profit_per_trade_middle.sum(): .2f}$")
print(f"The potential arbitrage profits on March 22nd is: {profit_per_trade_late.sum(): .2f}$")
# Out:
# The potential arbitrage profits on January 16th is:  6266.24$
# The potential arbitrage profits on February 17th is:  0.00$
# The potential arbitrage profits on March 22nd is:  0.00$

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Cumulative profits over time for the early profit per trade DataFrame using .cumsum()
cumulative_profit_early = profit_per_trade_early.cumsum()
cumulative_profit_middle = profit_per_trade_middle.cumsum()
cumulative_profit_late = profit_per_trade_late.cumsum()

# %%
# Plot of the cumulative sum of profits for the early profit per trade DataFrame.
cumulative_profit_early.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Plot of the cumulative sum of profits for the middle profit per trade DataFrame.
cumulative_profit_middle.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# Plot of the cumulative sum of profits for the late profit per trade DataFrame.
cumulative_profit_late.plot()
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** *Arbitrage opportunity became scarse over the two following months. I tried several different dates and they all came back unprofitable since they didn't cover the 1% for trading.*
